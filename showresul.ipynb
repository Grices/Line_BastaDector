# %%
import numpy as np
import pandas as pd
import tkinter as tk
import matplotlib.pyplot as plt
from turtle import color

# %%
path = "/home/penghua/BasestaDect/src/csv_data/dztz_0.csv" 
path1 = "/home/penghua/BasestaDect/src/csv_data/dztz_1.csv"
path2 = "/home/penghua/BasestaDect/src/csv_data/dztz_2.csv"
path3 = "/home/penghua/BasestaDect/src/csv_data/dztz_3.csv"
path4 = "/home/penghua/BasestaDect/src/csv_data/dztz_4.csv"
path5 = "/home/penghua/BasestaDect/src/csv_data/dztz_5.csv"
path6 = "/home/penghua/BasestaDect/src/csv_data/dztz_6.csv"
path7 = "/home/penghua/BasestaDect/src/csv_data/dztz_7.csv"
path8 = "/home/penghua/BasestaDect/src/csv_data/dztz_8.csv"
path9 = "/home/penghua/BasestaDect/src/csv_data/dztz_9.csv"
path10 = "/home/penghua/BasestaDect/src/csv_data/dztz_10.csv"
path11 = "/home/penghua/BasestaDect/src/csv_data/dztz_11.csv"
path12 = "/home/penghua/BasestaDect/src/csv_data/dztz_12.csv"
path13 = "/home/penghua/BasestaDect/src/csv_data/dztz_13.csv"
# path14 = "/home/penghua/BasestaDect/src/csv_data/dztz_14.csv"
# path15 = "/home/penghua/BasestaDect/src/csv_data/dztz_15.csv"
# path16 = "/home/penghua/BasestaDect/src/csv_data/dztz_16.csv"
# path17 = "/home/penghua/BasestaDect/src/csv_data/dztz_17.csv"
# path18 = "/home/penghua/BasestaDect/src/csv_data/dztz_18.csv"
# path19 = "/home/penghua/BasestaDect/src/csv_data/dztz_19.csv"
# path20 = "/home/penghua/BasestaDect/src/csv_data/dztz_20.csv"
# path21 = "/home/penghua/BasestaDect/src/csv_data/dztz_21.csv"
# path22 = "/home/penghua/BasestaDect/src/csv_data/dztz_22.csv"


dataframe = pd.read_csv(path, names=['x','y','dis','theta','power'])
dataframe1 = pd.read_csv(path1, names=['x','y','dis','theta','power'])
dataframe2 = pd.read_csv(path2, names=['x','y','dis','theta','power'])
dataframe3 = pd.read_csv(path3, names=['x','y','dis','theta','power'])
dataframe4 = pd.read_csv(path4, names=['x','y','dis','theta','power'])
dataframe5 = pd.read_csv(path5, names=['x','y','dis','theta','power'])
dataframe6 = pd.read_csv(path6, names=['x','y','dis','theta','power'])
dataframe7 = pd.read_csv(path7, names=['x','y','dis','theta','power'])
dataframe8 = pd.read_csv(path8, names=['x','y','dis','theta','power'])
dataframe9 = pd.read_csv(path9, names=['x','y','dis','theta','power'])
dataframe10 = pd.read_csv(path10, names=['x','y','dis','theta','power'])
dataframe11 = pd.read_csv(path11, names=['x','y','dis','theta','power'])
dataframe12 = pd.read_csv(path12, names=['x','y','dis','theta','power'])
dataframe13 = pd.read_csv(path13, names=['x','y','dis','theta','power'])
# dataframe14 = pd.read_csv(path14, names=['x','y','dis','theta','power'])
# dataframe15 = pd.read_csv(path15, names=['x','y','dis','theta','power'])
# dataframe16 = pd.read_csv(path16, names=['x','y','dis','theta','power'])
# dataframe17 = pd.read_csv(path17, names=['x','y','dis','theta','power'])
# dataframe18 = pd.read_csv(path18, names=['x','y','dis','theta','power'])
# dataframe19 = pd.read_csv(path19, names=['x','y','dis','theta','power'])
# dataframe20 = pd.read_csv(path20, names=['x','y','dis','theta','power'])
# dataframe21 = pd.read_csv(path21, names=['x','y','dis','theta','power'])
# dataframe22 = pd.read_csv(path22, names=['x','y','dis','theta','power'])

plt.figure(figsize = (3,3), dpi = 250) #, facecolor='#A9A9A9')
plt.tick_params(labelsize = 5, pad = 0.03) #设置刻度字体大小
# plt.tick_params(pad = 0.03) #刻度与坐标轴距离
plt.grid()
# canvas = plt.plot(dataframe['x'], dataframe['y'], marker='.', markersize=1, linewidth=0, color='chartreuse')
canvas = plt.plot(dataframe['x'], dataframe['y'], marker='.', markersize=2, linewidth=0.5, color='gold')
canvas = plt.plot(dataframe1['x'], dataframe1['y'], marker='.', markersize=2, linewidth=0.5, color='blue')
canvas = plt.plot(dataframe2['x'], dataframe2['y'], marker='.', markersize=2, linewidth=0.5, color='firebrick')
canvas = plt.plot(dataframe3['x'], dataframe3['y'], marker='.', markersize=2, linewidth=0.5, color='orangered')
canvas = plt.plot(dataframe4['x'], dataframe4['y'], marker='.', markersize=2, linewidth=0.5, color='chartreuse')
canvas = plt.plot(dataframe5['x'], dataframe5['y'], marker='.', markersize=2, linewidth=0.5, color='hotpink')
canvas = plt.plot(dataframe6['x'], dataframe6['y'], marker='.', markersize=2, linewidth=0.5, color='firebrick')
canvas = plt.plot(dataframe7['x'], dataframe7['y'], marker='.', markersize=2, linewidth=0.5, color='darkviolet')
canvas = plt.plot(dataframe8['x'], dataframe8['y'], marker='.', markersize=2, linewidth=0.5, color='dodgerblue')
canvas = plt.plot(dataframe9['x'], dataframe9['y'], marker='.', markersize=2, linewidth=0.5, color='lightcoral')
canvas = plt.plot(dataframe10['x'], dataframe10['y'], marker='.', markersize=2, linewidth=0.5, color='gold')
canvas = plt.plot(dataframe11['x'], dataframe11['y'], marker='.', markersize=2, linewidth=0.5, color='blue')
canvas = plt.plot(dataframe12['x'], dataframe12['y'], marker='.', markersize=2, linewidth=0.5, color='magenta')
canvas = plt.plot(dataframe13['x'], dataframe13['y'], marker='.', markersize=2, linewidth=0.5, color='darkorange')
# canvas = plt.plot(dataframe14['x'], dataframe14['y'], marker='.', markersize=2, linewidth=1, color='green')
# canvas = plt.plot(dataframe15['x'], dataframe15['y'], marker='.', markersize=2, linewidth=1, color='gold')
# canvas = plt.plot(dataframe16['x'], dataframe16['y'], marker='.', markersize=2, linewidth=1, color='blue')
# canvas = plt.plot(dataframe17['x'], dataframe17['y'], marker='.', markersize=2, linewidth=1, color='firebrick')
# canvas = plt.plot(dataframe18['x'], dataframe18['y'], marker='.', markersize=2, linewidth=1, color='orangered')
# canvas = plt.plot(dataframe19['x'], dataframe19['y'], marker='.', markersize=2, linewidth=0.5, color='darkviolet')
# canvas = plt.plot(dataframe20['x'], dataframe20['y'], marker='.', markersize=2, linewidth=0.5, color='dodgerblue')
# canvas = plt.plot(dataframe21['x'], dataframe21['y'], marker='.', markersize=2, linewidth=0.5, color='lightcoral')
# canvas = plt.plot(dataframe22['x'], dataframe22['y'], marker='.', markersize=2, linewidth=0.5, color='magenta')

canvas = plt.plot(0,0, marker='o', markersize=5, color='red')
canvas = plt.plot(-135.118, 61.7183, marker='*', markersize=5, color='green')
# canvas = plt.plot(-1174.5,218.604, marker='x', markersize=5, color='red')
# plt.savefig("line2.jpg",dpi=800)
